# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Questions:
#
# ### What is the wikipedia link to the algorithm?
#
# - https://en.wikipedia.org/wiki/Perceptron
#
# ### Which type of machine learning algorithm is this?
#
# - Usually supervised learning
#
# ### What is the best video tutorial on this algorithm?
#
# - https://www.youtube.com/watch?v=-1Z0hXNvO30
#
# ### What is the best text?
#
# - https://www.simplilearn.com/tutorials/deep-learning-tutorial/perceptron#:~:text=A%20Perceptron%20is%20a%20neural,value%20%E2%80%9Df(x).
#
# ### What is the best picture which describes the algorithm?
#
# - ![Neural Network](Images/NeuralNetwork.webp)
#
# ### What is one case for which the algorithm is used for?
#
# - Will add later with the use case with which I worked with

# %% [markdown]
# ## From scratch implementation

# %% [markdown]
# ## Imports

# %%
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data
#
# **Task:** Breast cancer dataset contains two classes (true or false) and several features about characteristics of a cell nuclei. Detect based on an input if someone has breast cancer or not.
#
# **Dataset**: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html

# %%
bc = datasets.load_breast_cancer()
X, y = bc.data, bc.target
X = np.delete(X, np.s_[0:25], axis=1)
xTest = X[130:] 
yTest = y[130:] 
X = X[:130]
y = y[:130]
thetas = np.ones(X[0].size)
learningRate = 0.01
iterations = 1000

# %% [markdown]
# 1. Hypothesis: $y = \theta_0 \cdot x_1 + \cdots + \theta_n \cdot x_n$
#
# 2. Cost = $\frac{1}{m} \sum^{m}_{j=1} y_j - h(z)$

# %%
def hypothesis(X, y):
    h = np.dot(X,y)
    return h

def sigmoid(z):
    s=1 / 1 + np.exp(-z)
    return s
    
def predict(X, y):
    #returns probability value
    p = sigmoid(hypothesis(X,y))
    return p


def costFunction(X, y, weigths):
    j = 1/len(X) * sum(y - predict(X,y))
    #j = 1/2 `* (y  - predict(X,y))
    return j

def updateWeights(X,y, weights):
