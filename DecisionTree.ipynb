# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Questions:
#
# ### What is the wikipedia link to the algorithm?
#
# - https://en.wikipedia.org/wiki/Decision_tree
#
# ### Link to paper?
#
# - https://www5.in.tum.de/lehre/seminare/datamining/ss17/paper_pres/08_decision_tree/paper.pdf
#
# ### Which type of machine learning algorithm is this?
#
# - Supervised learning
#
# ### What is the best video tutorial on this algorithm?
#
# - https://www.youtube.com/watch?v=eKD5gxPPeY0
#
# ### What is the best text?
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/classification_algos.html#decision-trees
#
# ### What is the best picture which describes the algorithm?
#
# - ![Decision Tree](Images/DecisionTree.jpeg)!
#
# ### What is one case for which the algorithm is used for?
#
# - wait for the example which I will implement

# %% [markdown]
# ## From scratch implementation

# %% [markdown]
# ### Steps for reproducing the algorithm
#
# 1.

# %% [markdown]
# ### Data
#
# **Task:**

# %% [markdown]
# ### Notes
#
# can use same data as before
